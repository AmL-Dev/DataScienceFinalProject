# %%
import pandas as pd

# %%
books_metadata = pd.read_csv('./data/books_metadata.csv')
books_metadata = books_metadata.set_index("book_id")

# %%
books_metadata.columns
# Out:
# Index(['title', 'series', 'author', 'description', 'genres', 'pages',
#        'publisher', 'firstPublishDate', 'awards', 'setting', 'coverImg'],
#       dtype='object')

# %%
books_metadata
# Out:
#                                                       title  \
# book_id
# 14796360                                   The Hunger Games
# 7743507           Harry Potter and the Order of the Phoenix
# 23390821                              To Kill a Mockingbird
# 1555826                                 Pride and Prejudice
# 28109798                                     The Book Thief
# ...                                                     ...
# 18652082                                         Undetected
# 33852466                                      Nameless Fate
# 270435    Heal Your Body: The Mental Causes for Physical...
# 11115191                                  Attracted to Fire
# 602931                                              Anasazi
#
#                                series  \
# book_id
# 14796360          The Hunger Games #1
# 7743507               Harry Potter #5
# 23390821        To Kill a Mockingbird
# 1555826                           NaN
# ...
