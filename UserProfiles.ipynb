# %%
import pandas as pd
import numpy as np
from collections import defaultdict
pd.set_option('display.max_rows', 5)

# %%
df_users = pd.read_csv("data/user_book_ratings.csv")
df_books = pd.read_csv("data/books_metadata.csv")

# %%
df_users.head(20)
# Out:
#     Unnamed: 0  user_id  book_id  rating
# 0            0        0  5602347       5
# 1            1        0       30       5
# ..         ...      ...      ...     ...
# 18          18        0  3709963       0
# 19          19        0   249158       4
#
# [20 rows x 4 columns]

# %%
df_books
# Out:
#         book_id                                      title  \
# 0      14796360                           The Hunger Games
# 1       7743507  Harry Potter and the Order of the Phoenix
# ...         ...                                        ...
# 26762  11115191                          Attracted to Fire
# 26763    602931                                    Anasazi
#
#                     series                                     author  \
# 0      The Hunger Games #1                            Suzanne Collins
# 1          Harry Potter #5  J.K. Rowling, Mary GrandPré (Illustrator)
# ...                    ...                                        ...
# 26762                  NaN             DiAnn Mills (Goodreads Author)
# 26763    Sense of Truth #2                              Emma Michaels
#
#                                              description  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1      There is a door at the end of a silent corrido...
# ...                                                  ...
# 26762  Special Agent Meghan Connors' dream of one day...
# 26763  'Anasazi', sequel to 'The Thirteenth Chime' by...
#
#                                                   genres pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# ...                                                  ...   ...
# 26762  ['Christian Fiction', 'Christian', 'Suspense',...   416
# 26763                         ['Mystery', 'Young Adult']   190
#
#                       publisher     firstPublishDate  \
# 0              Scholastic Press                  NaN
# 1               Scholastic Inc.             06/21/03
# ...                         ...                  ...
# 26762  Tyndale House Publishers  September 16th 2011
# 26763        Bokheim Publishing      August 3rd 2011
#
#                                                   awards  \
# 0      ['Locus Award Nominee for Best Young Adult Boo...
# 1      ['Bram Stoker Award for Works for Young Reader...
# ...                                                  ...
# 26762  ['HOLT Medallion by Virginia Romance Writers N...
# 26763                                                 []
#
#                                                  setting  \
# 0      ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1      ['Hogwarts School of Witchcraft and Wizardry (...
# ...                                                  ...
# 26762                     ['West Texas (United States)']
# 26763                                                 []
#
#                                                 coverImg
# 0      https://i.gr-assets.com/images/S/compressed.ph...
# 1      https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 26762  https://i.gr-assets.com/images/S/compressed.ph...
# 26763  https://i.gr-assets.com/images/S/compressed.ph...
#
# [26764 rows x 12 columns]

# %%
df_users = df_users.groupby('user_id')['book_id'].apply(list).reset_index(name='books_list')
df_ratings = df_users.groupby('user_id')['rating'].apply(list).reset_index(name='ratings_list')
df_ratings
# Out:
#         user_id                                       ratings_list
# 0             0  [5, 5, 5, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 5, 4, ...
# 1             1  [4, 4, 0, 5, 0, 0, 5, 0, 0, 3, 0, 5, 0, 5, 5, ...
# ...         ...                                                ...
# 819365   876143                           [4, 5, 4, 4, 5, 5, 5, 4]
# 819366   876144                                             [0, 0]
#
# [819367 rows x 2 columns]

# %% [markdown]
# From the above grouping, we can see that we have approx. 820k users in our database.<br/>
# df_users now contain all users with, for each user, a list of the books the have rated while df_ratings contain all users with a list of ratings they have given.

# %%
def list_converter(number_list): 
    author_list = []
    for i in number_list:
        name = df_books.loc[df_books["book_id"]==i,"author"].to_string(index=False)
        author_list.append(name)
    return author_list

# %% [markdown]
# Get authors for all books a given user has read and merge the two dataframes:

# %%
df_users["authors"]= df_users.apply(lambda row : list_converter(row["books_list"]),axis=1)
df_users["ratings"]= df_ratings["ratings_list"]
df_users
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20212/2347619151.py in <module>
# ----> 1 df_users["authors"]= df_users.apply(lambda row : list_converter(row["books_list"]),axis=1)
#       2 df_users["ratings"]= df_ratings["ratings_list"]
#       3 df_users
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9553             kwargs=kwargs,
#    9554         )
# -> 9555         return op.apply().__finalize__(self, method="apply")
#    9556
#    9557     def applymap(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py in apply(self)
#     744             return self.apply_raw()
#     745
# --> 746         return self.apply_standard()
#     747
#     748     def agg(self):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py in apply_standard(self)
#     871
#     872     def apply_standard(self):
# --> 873         results, res_index = self.apply_series_generator()
#     874
#     875         # wrap results
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     887             for i, v in enumerate(series_gen):
#     888                 # ignore SettingWithCopy here in case the user mutates
# --> 889                 results[i] = self.f(v)
#     890                 if isinstance(results[i], ABCSeries):
#     891                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp/ipykernel_20212/2347619151.py in <lambda>(row)
# ----> 1 df_users["authors"]= df_users.apply(lambda row : list_converter(row["books_list"]),axis=1)
#       2 df_users["ratings"]= df_ratings["ratings_list"]
#       3 df_users
#
# ~\AppData\Local\Temp/ipykernel_20212/1564972129.py in list_converter(number_list)
#       2     author_list = []
#       3     for i in number_list:
# ----> 4         name = df_book.loc[df_book["book_id"]==i,"author"].to_string(index=False)
#       5         author_list.append(name)
#       6     return author_list
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      40     @unpack_zerodim_and_defer("__eq__")
#      41     def __eq__(self, other):
# ---> 42         return self._cmp_method(other, operator.eq)
#      43
#      44     @unpack_zerodim_and_defer("__ne__")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    6241
#    6242         with np.errstate(all="ignore"):
# -> 6243             res_values = ops.comparison_op(lvalues, rvalues, op)
#    6244
#    6245         return self._construct_result(res_values, name=res_name)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     288
#     289     else:
# --> 290         res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     291
#     292     return res_values
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     163
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#     167         if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     239         if use_numexpr:
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#     243
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68     if _TEST_MODE:
#      69         _store_test_result(False)
# ---> 70     return op(a, b)
#      71
#      72
#
# KeyboardInterrupt:

# %%
# def averages(names, values):
#     # Group the items by name.
#     value_lists = defaultdict(list)
#     for name, value in zip(names, values):
#         value_lists[name].append(value)
    
#     # Take the average of each list.
#     # 9.2.5
#     result = {}
#     mean = sum(values) / len(values)
#     values_std = [(v - mean) for v in values]
#     for name, values in value_lists.items():
#         result[name] = sum(values_std) / float(len(values_std))
#     return result
     
def averages(names, non_stand_values):
    mean = sum(non_stand_values) / len(non_stand_values)
    values = [x - mean for x in non_stand_values]
    
    # Group the items by name.
    value_lists = defaultdict(list)
    for name, value in zip(names, values):
        value_lists[name].append(value)
        
    # Take the average of each list.
    result = {}
    for name, values in value_lists.items():
        result[name] = sum(values) / float(len(values))
    return result

df_users["author_rating"]= df_users.apply(lambda row : averages(row["authors"],row["ratings"]),axis=1)

    
averages(["john","danny","john","john"],[0,5,5,5])
# Out:
# {'john': -0.4166666666666667, 'danny': 1.25}

# %%
df_users
# Out:
#     user_id                                        movies_list  \
# 0         0  [5602347, 30, 12528798, 25026517, 835, 2202194...
# 1         1  [9003477, 627206, 395614, 1730369, 91760, 2409...
# ..      ...                                                ...
# 14       14  [17800990, 19009257, 29230876, 30741235, 33079...
# 15       15  [9926547, 633409, 1277772, 24473485, 13066640,...
#
#                                               authors  \
# 0   [Bill Bryson, J.R.R. Tolkien, Frank Herbert, N...
# 1   [Tracy Chevalier (Goodreads Author), Betty Edw...
# ..                                                ...
# 14  [Charlotte Stein (Goodreads Author), Beth Kery...
# 15  [Sara Gruen (Goodreads Author), John Fowles, U...
#
#                                               ratings  \
# 0   [5, 5, 5, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 5, 4, ...
# 1   [4, 4, 0, 5, 0, 0, 5, 0, 0, 3, 0, 5, 0, 5, 5, ...
# ..                                                ...
# 14  [5, 5, 5, 5, 5, 5, 5, 0, 0, 5, 0, 5, 0, 0, 0, ...
# 15  [3, 0, 3, 3, 3, 2, 0, 4, 4, 0, 3, 0, 5, 0, 4, ...
#
#                                         author_rating
# 0   {'Bill Bryson': 0.12264150943396235, 'J.R.R. T...
# 1   {'Tracy Chevalier (Goodreads Author)': 0.81999...
# ..                                                ...
# 14  {'Charlotte Stein (Goodreads Author)': 3.66071...
# 15  {'Sara Gruen (Goodreads Author)': 1.0612244897...
#
# [16 rows x 5 columns]

# %%
df = df_users.drop(columns=['authors', 'ratings'])
df.iloc[0,2]
# Out:
# {'Bill Bryson': 0.12264150943396235,
#  'J.R.R. Tolkien': 2.6226415094339623,
#  'Frank Herbert': 2.6226415094339623,
#  'Neal Stephenson (Goodreads Author)': 1.4226415094339624,
#  'Dan Harrington, Bill Robertie': 1.6226415094339623,
#  'Donald A. Norman': 2.6226415094339623,
#  'Khaled Hosseini (Goodreads Author), Berliani M....': 2.6226415094339623,
#  'Steven Pressfield (Goodreads Author)': 0.12264150943396235,
#  'David Allen': 1.6226415094339623,
#  'Ayn Rand, Leonard Peikoff (Goodreads Author) (A...': 2.6226415094339623,
#  'Jane Austen, Anna Quindlen (Introduction)': 2.6226415094339623,
#  'David McCullough': 0.12264150943396235,
#  'Lance Armstrong, Sally Jenkins': 2.6226415094339623,
#  'Malcolm Gladwell': 1.6226415094339623,
#  'Clayton M. Christensen, Michael E. Raynor': 1.6226415094339623,
#  'Clayton M. Christensen, L.J. Ganser (Narrator)': -2.3773584905660377,
#  'H.G. Wells, Greg Bear (Introduction), Carlo Pag...': -2.3773584905660377,
#  'Jack Kerouac': 1.6226415094339623,
#  'Naomi Klein': -2.3773584905660377,
#  'Douglas Coupland (Goodreads Author)': 1.6226415094339623,
#  'Ayn Rand, Leonard Peikoff (Goodreads Author) (I...': -0.8773584905660377,
#  'Louis de Bernières': 2.6226415094339623,
#  'Thomas L. Friedman, Đặng Ly (Translator)': -2.3773584905660377,
#  'Bernard Malamud, Kevin Baker (Goodreads Author)...': 1.6226415094339623,
#  'Mark Twain, Guy Cardwell (Notes), John Seelye (...': 2.6226415094339623,
#  'Andy Hunt (Goodreads Author), Dave Thomas (Good...': 2.6226415094339623,
#  'Nicholas Sparks (Goodreads Author)': -2.3773584905660377,
#  'Virginia Woolf': -2.3773584905660377,
#  'Omar El Akkad (Goodreads Author)': -2.3773584905660377,
#  'Peter F. Hamilton (Goodreads Author), Marta Gar...': -2.3773584905660377,
#  'Neil deGrasse Tyson (Goodreads Author)': -2.3773584905660377,
#  'Ron Chernow': -2.3773584905660377,
#  'Jocko Willink (Goodreads Author), Leif Babin': -2.3773584905660377,
#  'Graham Greene': -2.3773584905660377,
#  'Neal Stephenson (Goodreads Author), Nicole Gall...': -2.3773584905660377,
#  'Viet Thanh Nguyen (Goodreads Author)': -2.3773584905660377,
#  'Nathan Hill': -2.3773584905660377,
#  'F. Scott Fitzgerald, Amor Towles (Goodreads Aut...': -2.3773584905660377,
#  'Adam Gopnik': 1.6226415094339623,
#  'Patrick Süskind, John E. Woods (Translator)': 1.6226415094339623,
#  'Thomas L. Friedman': -2.3773584905660377,
#  'Paul Kalanithi': -2.3773584905660377,
#  'Natsuki Takaya, Alethea Nibley (Translator), At...': -2.3773584905660377,
#  'Niall Ferguson': -2.3773584905660377,
#  'Marshall B. Rosenberg, Arun Gandhi (Foreword by)': -2.3773584905660377,
#  'Ray Dalio (Goodreads Author) (Author/Narrator),...': -2.3773584905660377}

# %%
# %%file UP_MapReduce.py
 
from mrjob.job import MRJob
from mrjob.step import MRStep
import pandas as pd

df_book = pd.read_csv("data/books_metadata.csv")

class UP_MapReduce(MRJob): #class that inherits from MRJob 

    def string_to_list(self,s, awards=False):
        if awards:
            s_ = s.strip("[]").split(", ")
            s = []
            for aw in s_:
                s.append(aw[1:-1]) # Chop off the " from front and back, somewhat tideous but works
        else:
            s = s.strip("[]").split("', '")
            # Remove "'" from start of first and end of last item
            s[0] = s[0][1:]
            s[-1] = s[-1][:-1]
        return s

    def get_genre_list(self, bookID):
        return self.string_to_list(df_book[df_book["book_id"]==bookID]["genres"], awards=False)
        
    
    def steps(self):
        #need to define the order of mappers and reducers, so that the functions takes in the right key and value
        #only one mapper and reducer per step, so therefore need several steps
        #do we need the combiner between the mapper and reducer??
        return [ 
            MRStep(mapper=self.mapper_1, reducer=self.reducer_1),
#             MRStep(mapper=self.mapper_2, reducer = self.reducer_2),
#             MRStep(mapper = self.mapper_3, reducer = self.reducer_3),
#             MRStep(mapper = self.mapper_4)
        ]

    
    #key - ignored
    #values - corpus of documents (i.e. the data frame books_metadata)
    def mapper_1(self, _, line):  #each line is a row, i.e. a book 
        if line.find("book_id") == -1:
            list = line.split( ",")
            userID = list[2]
            bookID = list[3]
            rating = list[4]
            genres = self.get_genre_list(bookID)
            for genre in genres:
                yield (userID,genre), rating  # returns key-value pairs ((word, id), 1)

    #key - the key which was yielded by the mapper, i.e. (word, id). (key[0] = word, key[1]=id)
    #values - A generator which yields all values yielded by the mapper which correspond to key, i.e. a list of 1's
    def reducer_1(self, userID_genre, rating): 
        yield (userID_genre[0], userID_genre[1]), average(rating) # returns key-value pairs ((word, id), n)

if __name__ == '__main__':
    UP_MapReduce.run()
# Out:
# Overwriting UP_MapReduce.py

# %%
df = pd.read_csv("data/small_user_book_rating.csv")
df.iloc[0,1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20212/2291807073.py in <module>
# ----> 1 df = pd.read_csv("data/small_user_book_rating.csv")
#       2 df.iloc[0,1]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/small_user_book_rating.csv'

# %%
! python UP_MapReduce.py data/small_user_book_rating.csv > output
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\imad3\AppData\Local\Temp\UP_MapReduce.imad3.20221124.150757.757370
# Running step 1 of 1...
#
# Error while reading from C:\Users\imad3\AppData\Local\Temp\UP_MapReduce.imad3.20221124.150757.757370\step\000\mapper\00000\input:
#
# Traceback (most recent call last):
#   File "C:\Users\imad3\Desktop\DataScienceFinalProject\UP_MapReduce.py", line 57, in <module>
#     UP_MapReduce.run()
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\job.py", line 616, in run
#     cls().execute()
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\job.py", line 687, in execute
#     self.run_job()
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\job.py", line 636, in run_job
#     runner.run()
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\runner.py", line 503, in run
#     self._run()
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\sim.py", line 161, in _run
#     self._run_step(step, step_num)
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\sim.py", line 170, in _run_step
#     self._run_streaming_step(step, step_num)
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\sim.py", line 181, in _run_streaming_step
#     self._run_mappers_and_combiners(step_num, map_splits)
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\sim.py", line 219, in _run_mappers_and_combiners
#     self._run_multiple(
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\sim.py", line 130, in _run_multiple
#     func()
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\sim.py", line 724, in _run_mapper_and_combiner
#     run_mapper()
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\sim.py", line 746, in _run_task
#     invoke_task(
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\inline.py", line 133, in invoke_task
#     task.execute()
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\job.py", line 675, in execute
#     self.run_mapper(self.options.step_num)
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\job.py", line 760, in run_mapper
#     for k, v in self.map_pairs(read_lines(), step_num=step_num):
#   File "C:\Users\imad3\anaconda3\lib\site-packages\mrjob\job.py", line 830, in map_pairs
#     for k, v in mapper(key, value) or ():
#   File "C:\Users\imad3\Desktop\DataScienceFinalProject\UP_MapReduce.py", line 47, in mapper_1
#     genres = self.get_genre_list(bookID)
#   File "C:\Users\imad3\Desktop\DataScienceFinalProject\UP_MapReduce.py", line 24, in get_genre_list
#     return self.string_to_list(df_book[df_book["book_id"]==bookID]["genres"], awards=False)
#   File "C:\Users\imad3\Desktop\DataScienceFinalProject\UP_MapReduce.py", line 17, in string_to_list
#     s = s.strip("[]").split("', '")
#   File "C:\Users\imad3\anaconda3\lib\site-packages\pandas\core\generic.py", line 5487, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'Series' object has no attribute 'strip'

# %%
small_user_book_rating = df_user.head(1000)

# %%
small_user_book_rating.to_csv("data/small_user_book_rating.csv")

# %%
df_book = pd.read_csv("data/books_metadata.csv")


def string_to_list(s, awards=False):
        print()
        if awards:
            s_ = s.strip("[]").split(", ")
            s = []
            for aw in s_:
                s.append(aw[1:-1]) # Chop off the " from front and back, somewhat tideous but works
        else:
            s = s.strip("[]").split("', '")
            # Remove "'" from start of first and end of last item
            s[0] = s[0][1:]
            s[-1] = s[-1][:-1]
        return s

    
with open("data/small_user_book_rating.csv", 'r') as file:
    next(file) #Skip header
    while (line := file.readline().rstrip()):
        #Retrieve user, book id and associated rating
        _, _, user_id, book_id, rating = line.split(",")
        
        print(book_id)
        print(df_book[df_book["book_id"]==book_id]["genres"])
        
        break
# Out:
# 5602347
# Series([], Name: genres, dtype: object)
